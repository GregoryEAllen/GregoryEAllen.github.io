# %%
import pandas as pd
import yaml

# %%
y = '''\
- number: EE 380L.6
  prof: Lipovski
  title: Interfacing to Operating Systems
  semester: F 93
  area: Comp Eng Area I. Software
- number: EE 382N.10
  prof: Chase
  title: Parallel Computer Architecture
  semester: Sp 94
  area: Comp Eng Area II. Systems and Networks
- number: EE 381K.3
  prof: Smith
  title: Digital Filtering and Data Smoothing
  semester: F 94
  area: 'Supporting work: TISE'
- number: EE 381K.8
  prof: Bovik
  title: Digital Signal Processing
  semester: Sp 95
  area: 'Supporting work: TISE'
- number: EE 380L.5
  prof: Chase
  title: Engineering Programming Languages
  semester: F 95
  area: Comp Eng Area I. Software
- number: EE 380L
  prof: Ghosh
  title: Neural Networks for Pattern Recognition
  semester: Sp 96
  area: Comp Eng Area III. Applications
- number: EE 382M.1
  prof: Abraham
  title: Fault Tolerant Computing I
  semester: F 96
  area: Comp Eng Area IV. Design and Theory
- number: EE 382C
  prof: Evans
  title: Embedded Software Systems
  semester: Sp 97
  area: Comp Eng Area III. Applications
- number: EE 397K.1
  prof: Evans
  title: Real-time sonar beamforming on a workstation...
  semester: F 97
  area: Other Major Work
- number: CS 395T
  prof: Mok
  title: Real-time Systems
  semester: Sp 98
  area: 'Supporting work: Outside ECE'
- number: EE w398R
  prof: Evans
  title: Master's Report
  semester: Sum 98
  area: Other Major Work
- number: EE 382M
  prof: John
  title: Comp Perf Eval and Benchmarking
  semester: F 98
  area: Comp Eng Area II. Systems and Networks
- number: EE 397K.1
  prof: Evans
  title: Real-time sonar beamforming on a workstation...
  semester: F 98
  area: Other Major Work
- number: CS 392C
  prof: Browne
  title: Meth and Tech for Parallel Programming
  semester: Sp 99
  area: 'Supporting work: Outside ECE'
- number: CS 388G
  prof: Wong
  title: 'Algorithms: Technique and Theory'
  semester: F 99
  area: 'Supporting work: Outside ECE'
- number: EE 399R
  prof: Evans
  title: Dissertation
  semester: F 99
  area: Other Major Work
- number: M 365C
  prof: Bichteler
  title: Real Analysis
  semester: Sp 00
  area: 'Supporting work: Outside ECE'
- number: EE 399W
  prof: Evans
  title: Dissertation
  semester: Sp 00
  area: Other Major Work
- number: EE 399W
  prof: Evans
  title: Dissertation
  semester: F 00
  area: Other Major Work
- number: EE 380N
  prof: Baldick
  title: Optimization in Engineering Systems
  semester: Sp 01
  area: 'Supporting work: TISE'
- number: EE 399W
  prof: Evans
  title: Dissertation
  semester: Sp 01 - G
  area: Other Major Work
'''

yr = yaml.safe_load(y)

# %%
df = pd.DataFrame(yr)
print(df.iloc[:,:4].to_markdown(index = False))

# %%
print(df.sort_values(by='area').iloc[:,[0,2,4]].to_markdown(index = False))
